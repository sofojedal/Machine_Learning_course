# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'x1': [1, 2, 2.5, 4, 4.3],
                   'x2': [2.3, 3.7, 4, 4.2, 5],
                   'y': [0, 1, 1, 0, 1]})

# %% [markdown]
# Cual de todos los grafos divide emejor los datos

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.xlim(0, 6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# Sobre los parametros de x1
#
# Los horizontales sobre x2

# %% [markdown]
# axvline - Vertical
# _____
# axhline - horizontal

# %% [markdown]
# Vertical x1

# %% [markdown]
# if	x <= 1.5

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.axvline(1.5, color="r")
plt.xlim(0, 6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# if	x <= 2.25

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.axvline(2.25, color="r")
plt.xlim(0, 6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# if	x <= 3.25

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.axvline(3.25, color="r")
plt.xlim(0, 6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# if	x <= 4.15

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.axvline(4.15, color="r")
plt.xlim(0, 6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# Horizontal x2

# %% [markdown]
# if	x2 <= 3.0

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.axhline(3.0, color="r")
plt.xlim(0, 6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# if	x2 <= 3.85

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.axhline(3.85, color="r")
plt.xlim(0, 6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# if	x2 <= 4.1

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.axhline(4.1, color="r")
plt.xlim(0, 6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# if	x2 <= 4.6

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.axhline(4.6, color="r")
plt.xlim(0, 6)
plt.xlim(0, 6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# Para encontrar la mejor división de los datos se cruzaran las lineas

# %%
plt.scatter(df["x1"], df["x2"], c=df["y"])
plt.axvline(1.5, color = "r")
plt.axhline(4.1,xmin = 0.25, color="r")
plt.xlim(0.6)
plt.ylim(0.6)
# Out:
# (0.6, 5.135)
