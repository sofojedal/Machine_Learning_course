# %%
import numpy as np
import pandas as pd
import math
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , mean_squared_error, mean_absolute_error

# %%
x1_G1 = [[2], [4], [1]]
y_G1 = [["C1"], ["C0"], ["C0"]]

x1_G2 = [[3], [5], [7]]
y_G2 = [["C1"], ["C0"], ["C0"]]

x1_G3 = [[8], [10], [12]]
y_G3 = [["C1"], ["C1"], ["C0"]]

# %% [markdown]
# *Experimento 1*

# %%
# Entrenar a la máquina
model = DecisionTreeClassifier(max_depth=1)

model.fit(x1_G1 + x1_G2, y_G1 + y_G2)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(model)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 3.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.25, 0.25, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %%
#Validación
model.predict(x1_G3)
# Out:
# array(['C0', 'C0', 'C0'], dtype='<U2')

# %%
accuracy_score(y_G1 + y_G2, model.predict(x1_G1 + x1_G2))*100
# Out:
# 83.33333333333334

# %% [markdown]
# *Experimento 2*

# %%
# Entrenar a la máquina
model = DecisionTreeClassifier(max_depth=1)

model.fit(x1_G1 + x1_G3, y_G1 + y_G3)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(model)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 1.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.25, 'gini = 0.48\nsamples = 5\nvalue = [2, 3]')]

# %%
#Validación
model.predict(x1_G2)
# Out:
# array(['C1', 'C1', 'C1'], dtype='<U2')

# %%
accuracy_score(y_G1 + y_G3, model.predict(x1_G1 + x1_G3))*100
# Out:
# 66.66666666666666

# %% [markdown]
# *Experimento 3*

# %%
# Entrenar a la máquina
model = DecisionTreeClassifier(max_depth=1)

model.fit(x1_G2 + x1_G2, y_G2 + y_G3)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
plot_tree(model)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 4.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.75, 0.25, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]')]

# %%
#Validación
model.predict(x1_G1)
# Out:
# array(['C1', 'C1', 'C1'], dtype='<U2')

# %%
accuracy_score(y_G1 + y_G3, model.predict(x1_G1 + x1_G3))*100
# Out:
# 33.33333333333333

# %%
from sklearn.model_selection import cross_validate

# %%
x = [[2], [4], [1], [3], [5], [7], [8], [10], [12]]
y = [["C1"], ["C0"], ["C0"], ["C1"], ["C0"],  ["C0"], ["C1"], ["C1"], ["C0"]]

# %%
results = cross_validate(DecisionTreeClassifier(max_depth=1),
          x, y, cv=3, scoring="accuracy",
          return_train_score=True,
          return_estimator=True)
results
# Out:
# {'fit_time': array([0.00422454, 0.00124526, 0.00466919]),
#  'score_time': array([0.00662971, 0.00103831, 0.00196505]),
#  'estimator': [DecisionTreeClassifier(max_depth=1),
#   DecisionTreeClassifier(max_depth=1),
#   DecisionTreeClassifier(max_depth=1)],
#  'test_score': array([0.33333333, 0.33333333, 0.33333333]),
#  'train_score': array([0.83333333, 0.83333333, 0.66666667])}
